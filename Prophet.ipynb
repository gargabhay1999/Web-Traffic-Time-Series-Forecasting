# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from fbprophet import Prophet
import warnings

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
N = 0 # number of days for test split
pred_num = 60
i = 1800 # one example time series to train

# %%
all_data = pd.read_csv("../input/train_1.csv").T
key = pd.read_csv("../input/key_1.csv")

# %%
from operator import *

# %%
#Handle N/A
train= all_data
pages = train.iloc[:1]
train_cleaned = train.T.iloc[:,1:].fillna(method='ffill').T
dates=pd.Series(pd.date_range("01-01-2017","03-01-2017"))

# %%
#type(dates)
dates=dates.map(methodcaller('strftime', '%Y-%m-%d'))

# %%
submission_cols = ["page_date","Id","Visits"]
submission_1 = pd.DataFrame(columns=submission_cols)
submission_1=submission_1.set_index('page_date')
submission_1['page_date']=key['Page']
submission_1['Id']=key['Id']
data=train_cleaned.iloc[:,1].to_frame()

#print(len(data))

# %%
#fill outliers that are out of 1.5*std with rolling mean of 50 days

for i in range(20):
    data=train_cleaned.iloc[:,i].to_frame()
    data.columns = ['visits']
    with warnings.catch_warnings():
        warnings.filterwarnings('ignore')
    data['mean'] = pd.rolling_mean(data.visits,50,min_periods=1)
    std_mult = 1.5
    data.ix[np.abs(data.visits-data.visits.mean())>=(std_mult*data.visits.std()),'visits'] = data.ix[np.abs(data.visits-data.visits.mean())>=(std_mult*data.visits.std()),'mean']
    data.index = pd.to_datetime(data.index)

    #print(data.tail())

    #prophet expects the folllwing label names
    X = pd.DataFrame(index=range(0,len(data)))
    X['ds'] = data.index
    X['y'] = data['visits'].values
    X.tail()
    
    #print(X)
    m = Prophet(yearly_seasonality=True)
    m.fit(X)
    future = m.make_future_dataframe(periods=pred_num)
    #future.tail()

    forecast = m.predict(future)
    forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
    
    #print(forecast)
    
    m.plot(forecast)
    y_truth = train_cleaned.iloc[:,i].values
    y_forecasted = forecast.iloc[-N:,2].values
    y_forecasted_train = y_forecasted[:len(data)]
    #print(len(y_forecasted))
    #type(y_forecasted)
    for j in range(len(dates)):
        page_name = pages[i]["Page"]+"_"+dates[j]
        submission_1.loc[submission_1.page_date == page_name, 'Visits'] = y_forecasted[len(data)+j]
    print(i)    
        

    denominator = (np.abs(y_truth) + np.abs(y_forecasted_train))
    diff = np.abs(y_truth - y_forecasted_train) / denominator
    diff[denominator == 0] = 0.0
    print(200 * np.mean(diff))
print(submission_1)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,min_periods=1,center=False).mean()
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,min_periods=1,center=False).mean()
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 0
# 43.5884757749
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,min_periods=1,center=False).mean()
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 1
# 46.0952582398
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,min_periods=1,center=False).mean()
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 2
# 56.7159233773
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,min_periods=1,center=False).mean()
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 3
# 45.130984069
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,min_periods=1,center=False).mean()
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 4
# 62.3496936921
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,min_periods=1,center=False).mean()
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 5
# 38.2466776236
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,min_periods=1,center=False).mean()
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 6
# 46.9997378109
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,min_periods=1,center=False).mean()
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 7
# 64.127123307
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,min_periods=1,center=False).mean()
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 8
# 33.6227492278
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,min_periods=1,center=False).mean()
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 9
# 28.0358810809
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,min_periods=1,center=False).mean()
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 10
# 79.9712809064
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,min_periods=1,center=False).mean()
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 11
# 50.0106170095
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,min_periods=1,center=False).mean()
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 12
# 54.3267082472
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,min_periods=1,center=False).mean()
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 13
# 70.8355231218
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,min_periods=1,center=False).mean()
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 14
# 33.8333133922
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,min_periods=1,center=False).mean()
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 15
# 47.1512237903
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,min_periods=1,center=False).mean()
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 16
# 67.9461466388
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,min_periods=1,center=False).mean()
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 17
# 37.5214022219
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,min_periods=1,center=False).mean()
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 18
# 60.6268363069
# 19
# 66.3361631246
#                    Id Visits  \
# 0        bf4edcf969af    NaN
# 1        929ed2bf52b9    NaN
# 2        ff29d0f51d5c    NaN
# 3        e98873359be6    NaN
# 4        fa012434263a    NaN
# 5        48f1e93517a2    NaN
# 6        5def418fcb36    NaN
# 7        77bd08134351    NaN
# 8        5889e6dbb16f    NaN
# 9        5f21fef1d764    NaN
# 10       6f07e1b8815a    NaN
# 11       228e54b5dea0    NaN
# 12       da1b34963ed7    NaN
# 13       ab5ccefaa2db    NaN
# 14       cbf42873ebf1    NaN
# 15       ac67e35ed44e    NaN
# 16       88c098aa640d    NaN
# 17       7c72842a89d1    NaN
# 18       8ce002f2c329    NaN
# 19       5f72d9920560    NaN
# 20       f93afd7f5d9b    NaN
# 21       14011cb66f2d    NaN
# 22       0065551ac465    NaN
# 23       175f1872729e    NaN
# 24       31d756e83124    NaN
# 25       e186c2363c5e    NaN
# 26       3bce56c2b977    NaN
# 27       d497981dce77    NaN
# 28       c813cec10548    NaN
# 29       5123e0ed62c9    NaN
# ...               ...    ...
# 8703750  1fb8f902ad0f    NaN
# 8703751  0107f6d7cd82    NaN
# 8703752  30c402ed9e49    NaN
# 8703753  935fa0168d01    NaN
# 8703754  1140b428380e    NaN
# 8703755  cc5eadae0d7a    NaN
# 8703756  f923701cdb05    NaN
# 8703757  905679a20d39    NaN
# 8703758  642354a50690    NaN
# 8703759  7376c63bd4c1    NaN
# 8703760  1f0566b71f7e    NaN
# 8703761  938774bbb675    NaN
# 8703762  53c046bac8cb    NaN
# 8703763  ead2377353d3    NaN
# 8703764  efa87c7d5160    NaN
# 8703765  f239d6ceb17b    NaN
# 8703766  0fef0826b1bc    NaN
# 8703767  478d3c34b0c1    NaN
# 8703768  6a1b6e3028fc    NaN
# 8703769  3b5fb022accd    NaN
# 8703770  a4456a9d271d    NaN
# 8703771  d43a25cf4ef2    NaN
# 8703772  8f47d2e020cd    NaN
# 8703773  a78af728d84b    NaN
# 8703774  d1ba45c7ec08    NaN
# 8703775  f69747f5ee68    NaN
# 8703776  2489963dc503    NaN
# 8703777  b0624c909f4c    NaN
# 8703778  24a1dfb06c10    NaN
# 8703779  add681d54216    NaN
#
#                                                  page_date
# 0        !vote_en.wikipedia.org_all-access_all-agents_2...
# 1        !vote_en.wikipedia.org_all-access_all-agents_2...
# 2        !vote_en.wikipedia.org_all-access_all-agents_2...
# 3        !vote_en.wikipedia.org_all-access_all-agents_2...
# 4        !vote_en.wikipedia.org_all-access_all-agents_2...
# 5        !vote_en.wikipedia.org_all-access_all-agents_2...
# 6        !vote_en.wikipedia.org_all-access_all-agents_2...
# 7        !vote_en.wikipedia.org_all-access_all-agents_2...
# 8        !vote_en.wikipedia.org_all-access_all-agents_2...
# 9        !vote_en.wikipedia.org_all-access_all-agents_2...
# 10       !vote_en.wikipedia.org_all-access_all-agents_2...
# 11       !vote_en.wikipedia.org_all-access_all-agents_2...
# 12       !vote_en.wikipedia.org_all-access_all-agents_2...
# 13       !vote_en.wikipedia.org_all-access_all-agents_2...
# 14       !vote_en.wikipedia.org_all-access_all-agents_2...
# 15       !vote_en.wikipedia.org_all-access_all-agents_2...
# 16       !vote_en.wikipedia.org_all-access_all-agents_2...
# 17       !vote_en.wikipedia.org_all-access_all-agents_2...
# 18       !vote_en.wikipedia.org_all-access_all-agents_2...
# 19       !vote_en.wikipedia.org_all-access_all-agents_2...
# 20       !vote_en.wikipedia.org_all-access_all-agents_2...
# 21       !vote_en.wikipedia.org_all-access_all-agents_2...
# 22       !vote_en.wikipedia.org_all-access_all-agents_2...
# 23       !vote_en.wikipedia.org_all-access_all-agents_2...
# 24       !vote_en.wikipedia.org_all-access_all-agents_2...
# 25       !vote_en.wikipedia.org_all-access_all-agents_2...
# 26       !vote_en.wikipedia.org_all-access_all-agents_2...
# 27       !vote_en.wikipedia.org_all-access_all-agents_2...
# 28       !vote_en.wikipedia.org_all-access_all-agents_2...
# 29       !vote_en.wikipedia.org_all-access_all-agents_2...
# ...                                                    ...
# 8703750  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703751  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703752  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703753  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703754  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703755  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703756  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703757  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703758  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703759  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703760  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703761  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703762  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703763  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703764  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703765  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703766  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703767  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703768  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703769  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703770  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703771  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703772  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703773  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703774  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703775  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703776  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703777  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703778  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
# 8703779  龙生九子_zh.wikipedia.org_mobile-web_all-agents_20...
#
# [8703780 rows x 3 columns]

# %%
submission_1.to_csv('S1.csv')
